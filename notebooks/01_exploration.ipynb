# %%
import setup
from src.data import load_mnist, split_train_test


X, y = load_mnist()
X_train, X_test, y_train, y_test = split_train_test(X, y)

# %%
y.shape
# Out:
# (70000,)

# %%
from src.utils import plot_image

some_digit = X[1]
plot_image(some_digit)

# %%
y[1]
# Out:
# '0'
